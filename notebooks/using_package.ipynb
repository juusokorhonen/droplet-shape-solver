# %% [markdown]
# # Example of how to use the ADSA package.

# %%
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import adsa

# %%
R0 = 10.0e-3 # 10 mm
ca = 150.0

(_, X, Z) = adsa.solver.simulate_droplet_shape(R0, ca)
vol = adsa.analysis.calculate_volume(X, Z)
adsa.visualisation.plot_drop(X, Z, ca)

print(u"Contact angle: {:.4}°\nVolume: {:.4} uL".format(result.y[-1,0], vol*1e9))
# Out:
# Contact angle: 0.0°
# Volume: 3.695e+08 uL

# %%
bottom_area = np.pi*y[-1,0]**2
print(f"{bottom_area} mm2")
# Out:
# 21.520505868425772 mm2

# %%
X
# Out:
# array([0.00000000e+00, 9.99999904e-05, 1.99999967e-04, 1.19998918e-03,
#        2.19996164e-03, 5.56308654e-03, 8.92551365e-03, 1.22868205e-02,
#        2.15151820e-02, 3.07234370e-02, 3.99030952e-02, 6.10914877e-02,
#        8.19842428e-02, 1.02493278e-01, 1.22543917e-01, 1.61858680e-01,
#        1.98676211e-01, 2.32858737e-01, 2.64419034e-01, 2.93460743e-01,
#        3.39081163e-01, 3.78229694e-01, 4.11838790e-01, 4.40681837e-01,
#        4.65384255e-01, 5.00273899e-01, 5.26120916e-01, 5.44586902e-01,
#        5.56869031e-01, 5.65763075e-01, 5.64120985e-01, 5.54279274e-01,
#        5.38151099e-01, 5.02865407e-01, 4.90616321e-01])
